# %%
import requests
import json
import time
import csv
import spacy
from bs4 import BeautifulSoup
import ollama
# Out:
# Extracted: the Securities Exchange Act | AAPL | 2025-02-25 | entity.</p></div
# Extracted: N#LH)UECP6F8HM(3PHH(5'=]MI | AAPL | 2025-01-30 | entity.</p></div
# Extracted: M!C"R#Y)8/U>@GQY>OC_\[Y6!/X1VA6I[AN | AAPL | 2025-01-03 | entity.</p></div
# Extracted: the Securities Exchange Act | AAPL | 2024-10-31 | entity.</p></div
# Extracted: OX![9X]NG7BOKFT\'VJ;?D'WNZ | AAPL | 2024-09-10 | entity.</p></div
# Extracted: CFR | MSFT | 2025-01-29 | entity.</p></div
# Extracted: CFR | MSFT | 2025-01-22 | \XDV6F60>9(9 0
# MSP
# Extracted: HP%R3?-J+!@BXT;.L\ABOS2 | MSFT | 2024-12-11 | QS\(::^@=W)\T#L[/_MP00[.>E_.>MV+X[/3%6!PJ5%WVI1[*%2QQ9:4
# Extracted: Income Tax Liabilities | MSFT | 2024-12-03 | contextRef="C_64a494b0-c801-4baa-908b-757fe16d266e
# Extracted: GI | MSFT | 2024-10-30 | entity.</p></div
# Extracted: Plan | NVDA | 2025-03-07 | entity.</p></div
# Extracted: AVWELO | NVDA | 2025-02-26 | entity.</p></div
# Extracted: CFR | NVDA | 2025-01-17 | entity.</p></div
# Extracted: Data Center.</font></div><div style="margin-bottom:6pt;margin- | NVDA | 2024-11-20 | entity.</p></div
# Extracted: Board | NVDA | 2024-11-07 | entity.</p></div
# Extracted: KIEG?+&<H+F!9-OTR.*E_LK3O[-_LW[!:_8-NW[+Y*^5CKC;C&/ | GOOGL | 2025-03-18 | J%/M
# Extracted: K5'%!0;?5$)0K94]H1 | GOOGL | 2025-02-04 | entity.</p></div
# Extracted: SO5![K"L | GOOGL | 2024-10-29 | entity.</p></div
# Extracted: CFR | GOOGL | 2024-10-17 | entity.</p></div
# Extracted: I\X42.BP=)80 | GOOGL | 2024-09-24 | entity.</p></div
# Extracted: Q[CRLMJ';NU-NT(>JR.1JGCIJ2FC9W;Z | AMZN | 2025-02-06 | entity.</p></div
# Extracted: Q[CRLMJ';NU-NT(>JR.1JGCIJ2FC9W;Z | AMZN | 2024-10-31 | entity.</p></div
# Extracted: DoorDash | AMZN | 2024-08-01 | entity.</p></div
# Extracted: V!2;T$KS8DAJ;&
# M?*?V+0Y]V@W9I0H#J2*J#.M-742%>X$Z[I1KB_J,*%-1-9PROHWQ6,G816=- | AMZN | 2024-05-24 | order="440
# Extracted: MR3^[]\QE7X"E8U-W^ F+:Y&)0X+M,25%=Q$6H(L'RFL*P.>PPH$[ZSD*ODN\ | AMZN | 2024-05-14 | entity.</p></div
# Extracted: ML6CWFDW/B#6+RRN+-K)8IY(\11D8RN$&6 & 3F@#GH_B+XGGO([.+PM:^?= | TSLA | 2025-01-29 | NR!@5&6X_P
# Extracted: CFR | TSLA | 2025-01-02 | entity.</p></div
# Extracted: MND%R(U5V(;(:(.Q3&?D4Y![8-=7 | TSLA | 2024-10-23 | M W8
# Extracted: M2$)9TM[.K.X    K @  $0              @ &O | TSLA | 2024-10-02 | entity.</p></div
# Extracted: W*T,+Q#<K2*K,5R. 0%;@^E &
# MK14> | TSLA | 2024-07-23 | 337][<RQRSW<\LD?W'>0L5^A)XJ73-2ETS4!?1J'G5
# Extracted: M8,(]RI$ROC($YPDZ@B$7MOW]N>[6;GH?LQ^%BM&87,8@2KH[,YYDJ,$PI +&
# M41(.DL$H&+YM>Q@4$^Y3[DC6:<%QNME<07JX%DR4T,$89)3+H$<JD69 D!5 | META | 2025-02-20 | entity.</p></div
# Extracted: P3VH7K.)9A@:\TKUJ$)(HND'8,V2>[IFBG#S^0W1U | META | 2025-01-29 | entity.</p></div
# Extracted: Board | META | 2025-01-06 | entity.</p></div
# Extracted: N+TB | META | 2024-10-30 | entity.</p></div
# Extracted: Board | META | 2024-09-10 | entity.</p></div
# Extracted: ZV]SHMEK7VR"^DMI?$EUOGU>Z?R3;1PVMG]HMU@RW]GE% & | NFLX | 2025-01-21 | entity.</p></div
# Extracted: VI/AA\4/BIXC^''ACQ-_:?C/P[]I_M33/L%U%]G^SSK!-^]DB
# M6-MLKJORL | NFLX | 2024-10-17 | entity.</p></div
# Extracted: SPW | NFLX | 2024-08-01 | MH_X\_!WX!^#Q
# Extracted: N^)]CHGBO5_#VC>'M&MO FBZ;>>(X=>BGE>;4+J
# M.. | NFLX | 2024-07-18 | F
# M*IN1<6FXQPC
# Extracted: U/UT@71#52#ALFO8;W/H)U'H@[3QU2GT0%:)NK9@[)4MW | NFLX | 2024-06-07 | entity.</p></div
# Extracted: TD | AMD | 2025-03-24 | entity.</p></div
# Extracted: MPC | AMD | 2025-03-12 | FG \#IG8X!*9Y3[*.$S[5:"Q*:9'
# Extracted: the Securities Exchange Act | AMD | 2025-02-24 | entity.</p></div
# Extracted: MKIND | AMD | 2025-02-04 | M5;[./^>\/_?5'V<?\]X?^^J -K1/&NN:!8-86
# Extracted: Plan | AMD | 2024-11-18 | entity.</p></div
# Extracted: italic;font-weight:700;line-height:120%">Outside Activities | INTC | 2025-03-14 | P,#!@,#!@P(!P@
# Extracted: MHY | INTC | 2025-02-28 | MQG +=(L+IKP6*ML!"M\P/XB+?.I<[$+;24!R% *
# Extracted: weight:700;line-height:100%">21,618</font><font | INTC | 2025-01-30 | P,#!@,#!@P(!P@
# Extracted: Thomson S.A. | INTC | 2024-12-05 | F>
# Extracted: Board | INTC | 2024-12-03 | P,#!@,#!@P(!P@
# Extracted: P3VH7K.)9A@:\TKUJ$)(HND'8,V2>[IFBG#S^0W1U | ORCL | 2025-03-10 | entity.</p></div
# Extracted: TD | ORCL | 2025-02-03 | entity.</p></div
# Extracted: the Securities Exchange Act | ORCL | 2025-01-22 | entity.</p></div
# Extracted: CFR | ORCL | 2025-01-13 | P$(6O$F5
# Extracted: CS__?'Q8OESL C-#)3#L | ORCL | 2024-12-09 | entity.</p></div
# Extracted: NY?,M2J?\6H^_=;Y1JP?\]7<!+"V?0=28S- | IBM | 2025-03-12 | ML[BPLYO[+*QW6G"^817D
# Extracted: MPC | IBM | 2025-02-07 | entity.</p></div
# Extracted: CL20<>^.U3^._"8 | IBM | 2025-02-04 | M\@N+F2Z=7EVY6-8QA0.%  Z>PKL8_B
# Extracted: MQJC | IBM | 2025-01-30 | EN
# Extracted: ibm | IBM | 2025-01-29 | entity.</p></div
# Extracted: M1Y0,S2#?)$K WBW\=VO' | CSCO | 2025-02-24 | M)X4TIM2U&^FTW3KJSN=>U*=BD%KIT%_9;RLKS7,"(IDPJ57"=*E"RG4O9O9
# Extracted: W)33P#Z3A)IC | CSCO | 2025-02-12 | P$(6O$F5
# Extracted: EMEA | CSCO | 2025-02-12 | entity.</p></div
# Extracted: CISCO SYSTEMS, INC. | CSCO | 2024-12-11 | P$(6O$F5
# Extracted: EMEA | CSCO | 2024-11-13 | entity.</p></div
# Extracted: Board | PYPL | 2025-03-10 | entity.</p></div
# Extracted: Wells
# Fargo Bank | PYPL | 2025-03-06 | F>
# Extracted: M/6M3X\:RW_D54]Z;!*JP;!D#MF$Y18S9.-D%+B;W)/=+:BR-\9R5-3HS([#O | PYPL | 2025-02-25 | entity.</p></div
# Extracted: UMX6TQH[SQ!?*VTQVN\ QQG!_>R895X.,%CD*:_H0\*^%='\ | PYPL | 2025-02-04 | MX>Z5>QP
# Extracted: Plan | PYPL | 2025-01-22 | L4'#G5BJ12'BJA4R)XJN),Z/7-W[7!A0M
# M?A=\IX^NB
# Extracted: MU-XU/9 | ADBE | 2025-03-12 | entity.</p></div
# Extracted: the Committee of up to | ADBE | 2025-01-30 | entity.</p></div
# Extracted: Times New Roman">Section&nbsp;10.09 | ADBE | 2025-01-17 | entity.</p></div
# Extracted: RRS38&
# M#^"JKOWK;TH"OUTVV | ADBE | 2024-12-11 | entity.</p></div
# Extracted: VZUHR-SO]*Q&VBZRM&1?J-P=#WNNQIP | ADBE | 2024-09-12 | entity.</p></div
# Extracted: Salesforce | CRM | 2025-02-26 | entity.</p></div
# Extracted: Board | CRM | 2025-02-05 | entity.</p></div
# Extracted: Respect to Securities of Other Corporations</font><font | CRM | 2024-12-10 | entity.</p></div
# Extracted: Salesforce | CRM | 2024-12-03 | entity.</p></div
# Extracted: Times New Roman">/s/ Daniel | CRM | 2024-11-05 | MJ75_Q7N4U'[,P970M?Q3AG\9
# Extracted: Uber Technologies, Inc. | UBER | 2025-02-07 | entity.</p></div
# Extracted: EMEA | UBER | 2025-02-05 | entity.</p></div
# Extracted: Uber Technologies, Inc. | UBER | 2024-10-31 | entity.</p></div
# Extracted: Basis for Alternative Currencies</FONT></TD></TR></TABLE> | UBER | 2024-09-27 | entity.</p></div
# Extracted: Serif"><A HREF="#e24385a_046"><FONT STYLE="font: | UBER | 2024-09-09 | entity.</p></div
# Extracted: MWB2.39_WO+0?\_!8S,^_W%_/HA^Z7.3%_.T)?!V?1'HN"Y7/+]^>?+_X" | LYFT | 2025-03-03 | entity.</p></div
# Extracted: M.AU)TH!D$ | LYFT | 2025-02-11 | entity.</p></div
# Extracted: 0W_P"1!\??]?UI_P"@2U^<=?HY_P | LYFT | 2024-11-06 | entity.</p></div
# Extracted: the Securities Exchange Act | LYFT | 2024-09-04 | entity.</p></div
# Extracted: 0W_P"1!\??]?UI_P"@2U^<=?HY_P | LYFT | 2024-08-07 | entity.</p></div
# Extracted: APPLICABLE | SNAP | 2025-02-18 | entity.</p></div
# Extracted: \NMKN;PCX4\)^*(+66=9=#AT^Z@C4DN_E![<X'^
# MWE,_]-?:EU+1[CPY+X774+JQ2SBAN'NKN_MFGMQ?R | SNAP | 2025-02-04 | X%(\4
# Extracted: SUQDGCWH | SNAP | 2024-10-29 | 3ZA>"PLVG*%SN5%4
# Extracted: Times New Roman">SANTA | SNAP | 2024-09-13 | entity.</p></div
# Extracted: CXM\/Z3??8K | SNAP | 2024-08-01 | EI922
# Skipping SQ, CIK not found.
# Extracted: M>]]][;W/V==W?B6_YEISS3'N<8\Q1R&C2Z?[$K: | SHOP | 2025-03-19 | 3ZPB
# Extracted: MRR | SHOP | 2025-02-11 | X)_"KX06$T0(BEL_A
# Extracted: MYR | TWLO | 2025-02-13 | L!RY&X
# Extracted: ZAKS | TWLO | 2025-01-23 | entity.</p></div
# Extracted: Times New Roman">On December&#160;13 | TWLO | 2024-12-16 | entity.</p></div
# Extracted: label="loc_dei_EntityCentralIndexKey_b129a96e-1795 | TWLO | 2024-10-30 | entity.</p></div
# Extracted: Plan | TWLO | 2024-10-04 | entity.</p></div
# Extracted: LD;JQ5E8 | RBLX | 2025-02-06 | X1\
# M^HH
# Extracted: P>.*?IWB358=?AT7Q%IEM:7 | RBLX | 2024-10-31 | MA2K#$L
# Extracted: DFT | RBLX | 2024-10-03 | GNKXK8+2'NTFZ
# Extracted: Roblox Corp | RBLX | 2024-09-13 | entity.</p></div
# Extracted: the Securities Exchange Act | RBLX | 2024-08-26 | entity.</p></div
# Extracted: MZLB_EPY[EH-M:3C | DIS | 2025-03-24 | entity.</p></div
# Extracted: Times New Roman">SUMITOMO MITSUI BANKING | DIS | 2025-03-04 | entity.</p></div
# Extracted: the International Cricket Council | DIS | 2025-02-05 | MHJ *
# Extracted: MBE | DIS | 2025-01-06 | entity.</p></div
# Extracted: M3M&' | DIS | 2024-11-14 | entity.</p></div
# Extracted: TD STYLE="font | PEP | 2025-02-07 | entity.</p></div
# Extracted: K>]1EM9NVG6-=-],@,9ROI:@ P_D&
# MN;YA-^W>!M5"0X8SO'EW1=]J#[P(^C\ V<(J"/OJ2#(@D8#I$.2!7R">E | PEP | 2025-02-04 | S0
# M>
# Extracted: id="lab_pep_ZeroPointFivePercentNotesDue2028Member_documentation_en | PEP | 2024-12-11 | entity.</p></div
# Extracted: M^]'M6U*JLX | PEP | 2024-10-08 | S0
# M>
# Extracted: Board | PEP | 2024-09-20 | 3\8
# M
# Extracted: DI3HLJA[5'LBO6EZ2!>'B-I07 | KO | 2025-02-11 | entity.</p></div
# Extracted: M90 | KO | 2024-12-16 | entity.</p></div
# Extracted: CNU &EX)TO3-,^(6K6^E7>E06E | KO | 2024-12-11 | entity.</p></div
# Extracted: O59 | KO | 2024-10-23 | entity.</p></div
# Extracted: id="lab_dei_EntityAddressPostalZipCode_1080707d-d9ad-4109-aa8a-be09c8b4e321_terseLabel_en- | KO | 2024-10-17 | entity.</p></div
# Extracted: -3]N[<N+U/R9% N3VM_6]ND\31ZDV?\FB3= .?LO./:2P/ | MCD | 2025-03-11 | 3YP'9F*,-#UA&
# M*!;?)LB.QQ#<=[A&+7&7F@+)+@OX3[@TD[7LZ>YU(&/59<*F+@BB@7CR=1BD
# Extracted: \$\ D5V%UIM | MCD | 2025-03-04 | Y)_.LZS\;:%?7D%
# Extracted: H>:#.!E90JI | MCD | 2025-02-14 | M2I5=$G#@X1:(4 8[DL6?U]&_M-;($V*TDVCYGU$EU0AV:]^QKNH0Z+' +
# Extracted: MOMP./Q4H%QH#%B\D1TR;PW-F#@JVD4;9?)02,W@,ZUD8S"3H%T$KZI[_-$5/ | MCD | 2025-02-10 | R"@%7*KK@&#",IPI)-01_W":QC
# Extracted: Y2=&2BOMG | MCD | 2025-01-17 | entity.</p></div
# Extracted: M.^ | SBUX | 2025-03-14 | M2V3\[+
# Extracted: Replacement Grant | SBUX | 2025-03-04 | M/[[^)^KMNX#N3CE1()SF'M(YI
# Extracted: MFYN;BUM64V\3?F,_L!_[,V]9@6O1#>QW!&^V)WGKTPX_ &F3\V[IHUHD.*E7
# M$VJ D#<U<XQAHIW)P=5$_,VB9WX)8*^7#\JHD%/(QVF\[(K0 | SBUX | 2025-01-28 | X(I
# Extracted: MWS | SBUX | 2025-01-17 | O_&@7?(*BH-J?YEOW^T?G@\$ST^
# Extracted: KZ
# M A6R%F\@?9D"3I;J+,#0ER\-K>:L%,C05^EB]YT[PK.]!0H>SR>>]:9&UIVA | SBUX | 2025-01-16 | X(I
# Extracted: follow & | NKE | 2025-03-20 | entity.</p></div
# Extracted: XHZ6!=3V%'AY5^GZ :&+NBG8I$Z6?:]/2NU
# MH_#MT.*J7JY?K&%%K!NKN;/K?*KC]ODVM_5<^^:3Q'&QA"O>%S | NKE | 2025-03-10 | entity.</p></div
# Extracted: weight:700;line-height:100%">2,320</font><font | NKE | 2024-12-19 | M"F'65M&E($!W6.>\
# Extracted: Z16>%MB/Z9?OL&@V#K' | NKE | 2024-10-01 | entity.</p></div
# Extracted: NISYDO"%!=._1T&
# ML | NKE | 2024-09-20 | M \P7^W[ZRQ+IKEU'6V^B?X'"3^]?W:1T[YLNY"CN22'''MQ/8LX!=7X].[WZ
# Extracted: S"Z)D*5&$DOD#;7IY.#:%NNC'HZ &&
# MXGB4]<X"Q24K7F3:P33_?%"GR)MU3])Y | PFE | 2025-02-04 | entity.</p></div
# Extracted: Ongoing Cost Realignment | PFE | 2024-12-17 | entity.</p></div
# Extracted: IX & | PFE | 2024-10-29 | entity.</p></div
# Extracted: Board | PFE | 2024-10-15 | entity.</p></div
# Extracted: the Consolidated Statements of Operations | PFE | 2024-07-30 | entity.</p></div
# Extracted: MPC | JNJ | 2025-02-26 | MRO:[5Z_=K)B:,11-*3(C
# Extracted: TD | JNJ | 2025-02-20 | X0['^S;)@65=)H-]UJ-F]/AX,)0+4-$1O
# Extracted: X!B[T6"4IF-#_(3]<)(>:<ES,8$0
# M.5/2 &A@32F:+C-6Z@(Z,23#82SS | JNJ | 2025-01-22 | entity.</p></div
# Extracted: NJ | JNJ | 2024-10-15 | FLN4.2DBV6F]1\,7E
# M3L#R;1R.T0;C$#:4,%;OJ0
# Extracted: CP"#-+*/$AC+I4M$L"T"T | JNJ | 2024-09-20 | entity.</p></div
# Extracted: GI | MRNA | 2025-02-14 | entity.</p></div
# Extracted: DSMB | MRNA | 2025-01-13 | entity.</p></div
# Extracted: the Executive Committee | MRNA | 2024-11-07 | entity.</p></div
# Extracted: Regulation S-K.</span></div><div><span><br/></span></div><div><span | MRNA | 2024-10-02 | entity.</p></div
# Extracted: LRTD | MRNA | 2024-09-12 | entity.</p></div
# Extracted: TD | LLY | 2025-02-12 | entity.</p></div
# Extracted: B9:%Y-EZL'*0)?GJ,7Q:3\36 &>P9X"S'N"4OE | LLY | 2025-02-06 | P,#!@,#!@P(!P@
# Extracted: B7NMN^LK<^'3(XR;)/9&]\EM?&RG%>/&-B3[0DOX&EYCL | LLY | 2025-01-14 | F/V;"0@=%G
# Extracted: id="lab_dei_EntityFileNumber_d527bac2 | LLY | 2024-11-19 | F/V;"0@=%G
# Extracted: G\ &9@\'%6JTPUMF^Y[-74[17"+^D/QZ??V)W+*I'T3 | LLY | 2024-10-30 | P,#!@,#!@P(!P@
# Extracted: CFR | BMY | 2025-02-18 | ISO 3166-1
# Extracted: MFFM9=4FN9K:&Y\IIHV4!/F | BMY | 2025-02-06 | M@R\E0
# Extracted: MW9V^C_.'_/*/]?\ & | BMY | 2025-01-13 | 71_Y+6-2*LCJP\WS/;;LNZ*VK>*-
# Extracted: P,<"@#W*WE\^VBFQCS$#8],C-24@ 50H& | BMY | 2024-10-31 | K"%H4,@(<2[M
# Extracted: GTKI-+UG3]:@DFT^Y6>.-]C$ | BMY | 2024-07-26 | ^+W_(I6W_7\G_H#UT\]K'I?AB?^SH$BD@L
# MG$.Q1D$)D?J!0!1U/
# Extracted: MSU3#;#_+1T7</KWQ.IU([M\>4BF$$D8)\ +6&H:\5X]JO | GILD | 2025-03-12 | order="440
# Extracted: C_"C_B'J^- | GILD | 2025-02-11 | entity.</p></div
# Extracted: C74/^"#/[/WAVYT3X8 | GILD | 2024-11-20 | the Closing Date.</P>
# Extracted: MPC | GILD | 2024-11-06 | entity.</p></div
# Extracted: MPC | GILD | 2024-08-08 | entity.</p></div
# Extracted: M@W-QN(]54?XE | REGN | 2025-02-04 | entity.</p></div
# Extracted: F# &( | REGN | 2025-01-13 | IUM4%J[J9!:3
# Extracted: N>$4WDL]YH-LB+ED@TN J???!$\'L | REGN | 2024-10-31 | entity.</p></div
# Extracted: the Securities Exchange Act | REGN | 2024-10-07 | entity.</p></div
# Extracted: M@W-QN(]54?XE | REGN | 2024-08-01 | entity.</p></div
# Extracted: V!J7EB | CVS | 2025-02-12 | entity.</p></div
# Extracted: MQP | CVS | 2024-12-17 | entity.</p></div
# Extracted: Optional Sinking | CVS | 2024-12-10 | entity.</p></div
# Extracted: GI | CVS | 2024-12-09 | entity.</p></div
# Extracted: N1I*2%S(G,!4M*F1A | CVS | 2024-12-06 | entity.</p></div
# Extracted: Optum and UnitedHealthcare | UNH | 2025-01-16 | F-U
# Extracted: GI | UNH | 2024-12-04 | entity.</p></div
# Extracted: GI | UNH | 2024-12-03 | entity.</p></div
# Extracted: GI | UNH | 2024-11-26 | entity.</p></div
# Extracted: Optum and UnitedHealthcare | UNH | 2024-10-15 | BKZ-Y.P[$D
# Extracted: M^CD)YT([OK5TMJ9AO!0[@S'9PJ>^^ALHO5J?2 | VRTX | 2025-02-10 | entity.</p></div
# Extracted: M^GCZYS:]>J]-%&=2^&4-O8X | VRTX | 2024-12-20 | entity.</p></div
# Extracted: Non-GAAP Financial Information | VRTX | 2024-11-04 | entity.</p></div
# Extracted: MXR0;;IB.F:![7'O:/N/3$[!7W\L[W2W:_BZX | VRTX | 2024-08-16 | entity.</p></div
# Extracted: IW#%M,7*ER021\"/4!Y3/!C$Y. | VRTX | 2024-08-01 | entity.</p></div
# Extracted: N,?(<@X+ | XOM | 2025-01-31 | entity.</p></div
# Extracted: EI1L | XOM | 2025-01-07 | fact.</font></div><div><font><br></font></div><div><font
# Extracted: M$*_1;\ICH& " | XOM | 2024-11-12 | M=7I9I1>^@P6FFIPQJ9!HK2,RJ4B"1!?+/$?M1!(^\4FTO&'VP8AZ?S(GS-U7
# Extracted: DLO | XOM | 2024-11-01 | entity.</p></div
# Extracted: S]DG*N%A-\3]L-::MWHI:\!->/ZP*HC)YA)5?KLBF-=C(M^H;H?RF P,& | XOM | 2024-10-18 | P$(6O$F5
# Extracted: the Securities Exchange Act | CVX | 2025-03-17 | M>_9WZ_7#E4YX-592'-U?S]+'&JLB$Z8?IY/8L3T-N(&)U*O;2F63>
# Extracted: TD | CVX | 2025-02-26 | entity.</p></div
# Extracted: Board | CVX | 2025-01-31 | entity.</p></div
# Extracted: id="lab_dei_DocumentPeriodEndDate_f6fa7d98-9ad0-47ed-8fc8-76b96631ddb9_terseLabel_en-US | CVX | 2025-01-31 | entity.</p></div
# Extracted: italic;font-weight:700;line-height:112%">Chairman | CVX | 2024-12-10 | entity.</p></div
# Extracted: MCAXA[D[P35&NBH6ZS;P**-(6?Y63EQ^EE!*BU6U=_(MV &V[B:!(@H013(>B
#  | COP | 2025-02-06 | entity.</p></div
# Extracted: italic 10pt | COP | 2025-01-28 | order="440
# Extracted: TD STYLE="font | COP | 2024-12-30 | M<_T
# Extracted: E)'(S<%U_5+& | COP | 2024-12-10 | Charter)</p
# Extracted: TD STYLE="font | COP | 2024-12-05 | MS!<C'S8R 7IJ>'@V"2;W2PRZC46D_9-81#8>+2(_,)5=<*M
# Extracted: U*R | SLB | 2025-01-17 | ChampionX
# Extracted: U*R | SLB | 2024-10-18 | F^5-XOSYZ
# Extracted: U*R | SLB | 2024-07-19 | ChampionX
# Extracted: Olivier Le Peuch | SLB | 2024-06-17 | ISO 3166-1
# Extracted: M-]WV;FW&!<8"O9,39?L<)8/!QEMX\%?O-Q2]YSFXFAAAU>,5#ZED&Q[T.4UR | SLB | 2024-05-29 | entity.</p></div
# Extracted: D.[E&36/12J'/Y | HAL | 2025-01-22 | entity.</p></div
# Extracted: CFR | HAL | 2025-01-08 | CA
# M2TZR
# Extracted: T+$/GV(YS7WY^W5_R1&/ | HAL | 2024-11-07 | entity.</p></div
# Extracted: CFR | HAL | 2024-09-03 | entity.</p></div
# Extracted: CFR | HAL | 2024-08-23 | entity.</p></div
# Extracted: KYC | F | 2025-02-05 | F+U!;7'GB5"Q4+DJN
# M&W #'
# Extracted: MCLP'0$X4#OU- &6?B.1IWAR8:>&N=5N!'/$).+:/SA"SDXY^=E '&> | F | 2025-02-05 | entity.</p></div
# Extracted: M*.OJ]0[;I3L3J&*=RNKT]<X?)^^(W?GES8L7K_Y%R%^_'K^?'-3Q8@Y5.]EO | F | 2025-01-23 | entity.</p></div
# Extracted: M^J"C@=_6NUT3Q%<Z_P"-[V.TG!T | F | 2025-01-03 | 3^(-"M/"OBKQ3;Z3+<QP'P;/-&C
# MW#R&$^;CY2Q
# Extracted: NQ:<Q6&TCU-<"&RY=9LZSEA9 | F | 2024-12-16 | entity.</p></div
# Extracted: A8^.M | GM | 2025-02-26 | entity.</p></div
# Extracted: M            &Q#B#G1F)>P\9R^]SJ | GM | 2025-01-28 | entity.</p></div
# Extracted: TD | GM | 2024-12-10 | entity.</p></div
# Extracted: SAIC | GM | 2024-12-04 | entity.</p></div
# Extracted: M            &Q#B#G1F)>P\9R^]SJ | GM | 2024-10-22 | entity.</p></div
# Extracted: C R-3 S,3@N>'-D4$L | QCOM | 2025-03-20 | entity.</p></div
# Extracted: italic;font-weight:700;line-height:100%">Supplemental Revenue | QCOM | 2025-02-05 | entity.</p></div
# Extracted: M9R9NX(D OX#\@1HAVP | QCOM | 2024-12-12 | entity.</p></div
# Extracted: NWW | QCOM | 2024-11-06 | entity.</p></div
# Extracted: Board | QCOM | 2024-10-09 | entity.</p></div
# Extracted: GI | AVGO | 2025-03-06 | M7&3E]M[T-LU3NYOKE%3742PK;U(=GBR0'U
# Extracted: CFR | AVGO | 2025-01-13 | entity.</p></div

# %%
# Load NLP model and set max length
nlp = spacy.load("en_core_web_sm")
nlp.max_length = 1_500_000  # Avoid memory error

# Function to get CIK from Ticker
def get_cik_from_ticker(ticker):
    url = "https://www.sec.gov/files/company_tickers.json"
    headers = {"User-Agent": "Larissa Iacobescu (la641245@ucf.edu)"}  
    
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print(f"Error {response.status_code}: Could not fetch CIK.")
        return None

    data = response.json()
    ticker_to_cik = {str(info["ticker"]).upper(): str(info["cik_str"]).zfill(10) for info in data.values()}
    
    return ticker_to_cik.get(ticker.upper())

# %%
# Function to get 8-K Filings
def get_8k_filings(cik, count=5):
    url = f"https://data.sec.gov/submissions/CIK{cik}.json"
    headers = {"User-Agent": "Larissa Iacobescu (la641245@ucf.edu)"}
    
    response = requests.get(url, headers=headers)
    time.sleep(1)

    if response.status_code != 200:
        print(f"Error {response.status_code}: Could not fetch filings.")
        return []

    data = response.json()
    if "filings" not in data or "recent" not in data["filings"]:
        print("Error: Invalid SEC data format.")
        return []

    recent_filings = data["filings"]["recent"]
    filings = [
        {
            "filing_date": recent_filings["filingDate"][i],
            "accession_number": recent_filings["accessionNumber"][i],
            "filing_url": f"https://www.sec.gov/Archives/edgar/data/{cik}/{recent_filings['accessionNumber'][i].replace('-', '')}/{recent_filings['accessionNumber'][i]}.txt"
        }
        for i in range(len(recent_filings["form"]))
        if recent_filings["form"][i] == "8-K"
    ][:count]

    return filings

# %%
# Function to fetch text from 8-K filing
def fetch_filing_text(cik, accession_number):
    url = f"https://www.sec.gov/Archives/edgar/data/{cik}/{accession_number.replace('-', '')}/{accession_number}.txt"
    headers = {"User-Agent": "Larissa Iacobescu (la641245@ucf.edu)"}

    response = requests.get(url, headers=headers)
    time.sleep(1)

    if response.status_code == 200:
        return response.text
    else:
        print(f"Error fetching filing {accession_number}: {response.status_code}")
        return None

# %%
# Function to extract entities (Company Name & Product) using NER
def extract_entities(text, chunk_size=100000):
    company_names = set()
    product_names = set()

    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        doc = nlp(chunk)

        for ent in doc.ents:
            if ent.label_ == "ORG":
                company_names.add(ent.text)
            elif ent.label_ == "PRODUCT":
                product_names.add(ent.text)

    return (next(iter(company_names), None), next(iter(product_names), None))

# %%
# Function to summarize product description using DeepSeek
def generate_summary(text):
    prompt = f"Summarize the following product description in less than 180 characters:\n\n{text}"
    
    response = ollama.chat(model="deepseek-r1:1.5b", messages=[{"role": "user", "content": prompt}])
    
    return response['message']['content'] if response else "No summary available."

# %%
# Function to save extracted data to CSV
def save_to_csv(data, filename="sec_8k_filings2.csv"):
    with open(filename, mode="w", newline="", encoding="utf-8") as file:
        writer = csv.writer(file)
        writer.writerow(["Company Name", "Stock Name", "Filing Time", "New Product", "Product Description"])
        writer.writerows(data)

# List of tickers
tickers = ["AAPL", "MSFT", "NVDA", "GOOGL", "AMZN", "TSLA", "META", "NFLX", "AMD", "INTC", 
           "ORCL", "IBM", "CSCO", "PYPL", "ADBE", "CRM", "UBER", "LYFT", "SNAP", "SQ", 
           "SHOP", "TWLO", "RBLX", "BABA", "DIS", "PEP", "KO", "MCD", "SBUX", "NKE",
           "PFE", "JNJ", "MRNA", "LLY", "BMY", "GILD", "REGN", "CVS", "UNH", "VRTX",
           "XOM", "CVX", "BP", "TTE", "COP", "SLB", "HAL", "F", "GM", "TSM", "ASML",
           "QCOM", "AVGO", "TXN", "NXPI", "LRCX", "AMAT", "MU", "STX", "WDC", "V",
           "MA", "AXP", "JPM", "GS", "BAC", "C", "MS", "WFC", "T", "VZ", "TMUS",
           "BA", "LMT", "NOC", "RTX", "GD", "HON", "CAT", "DE", "MMM", "GE",
           "PG", "CL", "KMB", "EL", "WMT", "TGT", "COST", "HD", "LOW", "BBY", "DG", "DLTR"]

# Processing multiple tickers
structured_data = []

for ticker in tickers[:100]:  # Limit to 100 tickers
    cik = get_cik_from_ticker(ticker)
    if not cik:
        print(f"Skipping {ticker}, CIK not found.")
        continue

    filings = get_8k_filings(cik, count=5)
    for filing in filings:
        filing_text = fetch_filing_text(cik, filing["accession_number"])
        if not filing_text:
            continue

        company, product = extract_entities(filing_text)
        if company and product:
            summary = generate_summary(filing_text)
            structured_data.append([company, ticker, filing["filing_date"], product, summary])
            print(f"Extracted: {company} | {ticker} | {filing['filing_date']} | {product}")

# Save to CSV
save_to_csv(structured_data)
print("✅ CSV file saved successfully!")
